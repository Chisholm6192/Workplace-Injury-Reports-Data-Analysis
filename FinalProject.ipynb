# %% [markdown]
# # Final Assignment
#
# Group Members: Michael D'Onofrio,
#
# Student IDs:  169032946 ,

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df_ci = pd.read_csv('C:/Users/Michael/Documents/CP321/FinalAssignment/criticalInjury.csv')
df_f = pd.read_csv('C:/Users/Michael/Documents/CP321/FinalAssignment/fatalities.csv')
df_o = pd.read_csv('C:/Users/Michael/Documents/CP321/FinalAssignment/orders.csv')

# %%
df_ci.head()
# Out:
#    Calendar Year  Construction Health and Safety Program  \
# 0           2011                                     180
# 1           2012                                     190
# 2           2013                                     186
# 3           2014                                     200
# 4           2015                                     162
#
#    Industrial Health and Safety Program  Health Care Program  \
# 0                                   598                 26.0
# 1                                   690                  NaN
# 2                                   703                  NaN
# 3                                   865                  NaN
# 4                                   683                  NaN
#
#    Mining Health and Safety Program  Program Unassigned  Total
# 0                                31               131.0    966
# 1                                24               243.0   1147
# ...

# %%
df_o = df_o.transpose()

df_o.head()
# Out:
#                                                           0  \
# Program/Fiscal Year  Construction Health and Safety Program
# 2011/12                                              60,340
# 2012/13                                              59,670
# 2013/14                                              61,877
# 2014/15                                              63,859
#
#                                                         1  \
# Program/Fiscal Year  Industrial Health and Safety Program
# 2011/12                                            70,369
# 2012/13                                            66,910
# 2013/14                                            58,284
# 2014/15                                            59,993
#
#                                                     2  \
# Program/Fiscal Year  Mining Health and Safety Program
# 2011/12                                         3,443
# 2012/13                                         2,930
# ...
